# %% [markdown]
# # Resources

# %% [markdown]
# ##### [Forecasting: Principles & Practice (Rob J Hyndman)](https://robjhyndman.com/uwafiles/fpp-notes.pdf) (doc in repo)
#
# ##### [Time Series Analysis with Python (Dennis Tay)](https://www.researchgate.net/publication/360491195_Time_series_analysis_with_python) (doc in repo)
#
# ##### GITHUB [Time series analysis with Python (Filippo Maria Bianchi)](https://filippomb.github.io/python-time-series-handbook/notebooks/00/intro.html)
# * [Github repo] (https://github.com/FilippoMB/python-time-series-handbook)

# %% [markdown]
# #### Prophet
# * Web [Prophet: Forecasting at scale](https://facebook.github.io/prophet/)
# * Doc site [Prophet: Quick Start Python API](https://facebook.github.io/prophet/docs/quick_start.html)
# * GITHUB [prophet](https://github.com/facebook/prophet)

# %% [markdown]
# ##### [TOP 5 Time Series Forecasting Libraries in 2025 for Python](https://medium.com/@ibtissam.makdoun/top-5-time-series-forecasting-libraries-in-2025-for-python-a6963d1b6ece) (Date reviewed: 2025-10-18)
#
# * [𝗣𝗿𝗼𝗽𝗵𝗲𝘁 — 19.7𝗸 ⭐](https://github.com/facebook/prophet)
# * [𝗡𝗶𝘅𝘁𝗹𝗮 𝗦𝗲𝘁 𝗼𝗳 𝗟𝗶𝗯𝗿𝗮𝗿𝗶𝗲𝘀 — 11.3𝗸 ⭐](https://www.nixtla.io/)
#     * [statsforecast](https://github.com/Nixtla/statsforecast)
#     * [neuralforecast](https://github.com/Nixtla/neuralforecast)
#     * [TimeGPT](https://github.com/Nixtla/nixtla)
# * [SKtime — 9.3𝗸 ⭐](https://github.com/sktime/sktime)
# * [Darts — 9𝗸 ⭐](https://github.com/unit8co/darts)
# * [GluonTS — 5𝗸 ⭐](https://github.com/facebook/prophet)

# %% [markdown]
# #### Datcamp
# * [Time Series Forecasting Tutorial](https://www.datacamp.com/tutorial/tutorial-time-series-forecasting)
# * [ARIMA for Time Series Forecasting: A Complete Guide](https://www.datacamp.com/tutorial/arima)
# * [Time Series Analysis with Python by Alex Yarosh](https://github.com/datacamp/time-series-analysis-in-python-live-training)
# * [AI Time Series Forecasting: A Beginners' Guide](https://www.datacamp.com/blog/ai-time-series-forecasting)

# %% [markdown]
# #### [Open Machine Learning Course](https://mlcourse.ai/book/index.html)
